# %%
import tabula

# %%
pdf1_path = "D:/Dataset/pdfimages/data.pdf"
pdf2_path = "D:/Dataset/pdfimages/campaign_donors.pdf"

# %%
df_data = tabula.read_pdf(pdf1_path, stream=True, pages= 'all', multiple_tables=False)

# %%
print(len(df_data))
# Out:
# 1

# %%
df_data[0]
# Out:
#            Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec   vs   am  \
# 0           Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46  0.0  1.0
# 1       Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02  0.0  1.0
# 2          Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61  1.0  1.0
# 3      Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44  1.0  0.0
# 4   Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02  0.0  0.0
# ..                ...   ...  ...    ...  ...   ...    ...    ...  ...  ...
# 57               16.5    VC  1.0    NaN  NaN   NaN    NaN    NaN  NaN  NaN
# 58               16.5    VC  1.0    NaN  NaN   NaN    NaN    NaN  NaN  NaN
# 59               15.2    VC  1.0    NaN  NaN   NaN    NaN    NaN  NaN  NaN
# 60               17.3    VC  1.0    NaN  NaN   NaN    NaN    NaN  NaN  NaN
# 61               22.5    VC  1.0    NaN  NaN   NaN    NaN    NaN  NaN  NaN
#
#     gear  carb
# 0    4.0   4.0
# 1    4.0   4.0
# 2    4.0   1.0
# ...

# %%
df_data2 = tabula.read_pdf(pdf2_path, stream=True, pages= 'all', multiple_tables=False)

# %%
print(len(df_data2))
# Out:
# 1

# %%
df_data2[0]
# Out:
#                        Apellido Nombre  Unnamed: 1   Matricula           Cuit  \
# 0                     MENA JUAN MARTÍN         NaN  27.083.460  20-27083460-5
# 1                         MOLLE MATÍAS         NaN  25.348.547  20-25348547-8
# 2               MOLLEVI FEDERICO OSCAR         NaN  25.028.246  20-25028246-0
# 3                 PERAZZO PABLO DANIEL         NaN  25.348.394  20-25348394-7
# 4               PICARDI FRANCO EDUARDO         NaN  27.382.271  20-27382271-3
# 5                PISONI CARLOS ENRIQUE         NaN  26.034.823  20-26034823-0
# 6               PONTORIERO MARÍA PAULA         NaN  23.249.597  27-23249597-4
# 7                 PULESTON JUAN MIGUEL         NaN  11.895.661  20-11895661-4
# 8                   REMÓN MABEL AURORA         NaN  11.292.939  27-11292939-3
# 9                  SARRABAYROUSE DIEGO         NaN  24.662.899  20-24662899-9
# 10               SPATOLA ANALÍA CARMEN         NaN  24.560.922  27-24560922-7
# ...
